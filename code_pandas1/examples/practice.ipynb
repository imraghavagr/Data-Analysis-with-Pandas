# %%
import pandas as pd

# %%
ds1 = pd.read_csv('ex1.csv')
ds1.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
ds2 = pd.read_csv('test.tsv', sep = '\t')

# %%
ds2 = pd.read_csv('ex2.csv', header = None, names = ['a', 'b', 'c', 'd', 'e', 'f'])
ds2.head()
ds2.isnull()
# Out:
#        a      b      c      d      e     f
# 0  False  False  False  False  False  True
# 1  False  False  False  False  False  True
# 2  False  False  False  False  False  True

# %%
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
pwd
# Out:
# 'C:\\Users\\HP\\codes\\iNeuron\\Data Analysis with pandas\\code_pandas1\\examples'

# %%
ds = pd.read_csv('csv_mindex.csv', index_col = ['key1', 'key2'])

# %%
ds.head()
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10

# %%
a = pd.read_csv('ex4.csv', skiprows = [0,2,3])

# %%
a.head(10)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
data = pd.read_json('example.json')

# %%
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = pd.read_csv('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
data.shape
# Out:
# (0, 2296)

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40054',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40054/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40054/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/40054/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/40054',
#   'id': 816691482,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTgwMzA5OTc4',
#   'number': 40054,
#   'title': 'PERF: NDArrayBacked in cython',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
data = resp.json
