# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
a = np.array(list(df.index))
a
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
b = np.array(list(df1.index))
b
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %%
#renaming the 'Indicator' column to 'Indicator_id'

# %%
df.rename(columns = {'Indicator':'Indicator_id', 'PUBLISH STATES':'Publish States','WHO region':'WHO Region'}, inplace = True)

# %%
df.head(2)
# Out:
#                        Indicator_id Publish States  Year WHO Region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Arrange values of a particular column in ascending oder

# %%
df.sort_values(by = ['Year'], inplace = True)
df
# Out:
#                                          Indicator_id Publish States  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1270                 Life expectancy at birth (years)      Published  1990
# 3193                 Life expectancy at birth (years)      Published  1990
# 3194                 Life expectancy at birth (years)      Published  1990
# 3197                Life expectancy at age 60 (years)      Published  1990
# ...                                               ...            ...   ...
# 1316                 Life expectancy at birth (years)      Published  2012
# 3141                 Life expectancy at birth (years)      Published  2012
# 3139                Life expectancy at age 60 (years)      Published  2012
# 3156                Life expectancy at age 60 (years)      Published  2012
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#            WHO Region World Bank income group  \
# ...

# %%
df.sort_values(by = ['Year','Country'], inplace = True)

# %%
df
# Out:
#                                          Indicator_id Publish States  Year  \
# 1395                Life expectancy at age 60 (years)      Published  1990
# 965                  Life expectancy at birth (years)      Published  1990
# 2959                Life expectancy at age 60 (years)      Published  1990
# 1792                 Life expectancy at birth (years)      Published  1990
# 554                  Life expectancy at birth (years)      Published  1990
# ...                                               ...            ...   ...
# 3546  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 1514                Life expectancy at age 60 (years)      Published  2012
# 3106                 Life expectancy at birth (years)      Published  2012
# 3104                 Life expectancy at birth (years)      Published  2012
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
# ...

# %%
# Making 'country' column as the first column of the given df

# %%
#Method 1
countries = df['Country']
df.drop(labels=['Country'], axis=1, inplace = True)
df.insert(0, 'Country', countries)
df
# Out:
#           Country                                     Indicator_id  \
# 1395  Afghanistan                Life expectancy at age 60 (years)
# 965   Afghanistan                 Life expectancy at birth (years)
# 2959  Afghanistan                Life expectancy at age 60 (years)
# 1792  Afghanistan                 Life expectancy at birth (years)
# 554   Afghanistan                 Life expectancy at birth (years)
# ...           ...                                              ...
# 3546     Zimbabwe  Healthy life expectancy (HALE) at birth (years)
# 1514     Zimbabwe                Life expectancy at age 60 (years)
# 3106     Zimbabwe                 Life expectancy at birth (years)
# 3104     Zimbabwe                 Life expectancy at birth (years)
# 4655     Zimbabwe  Healthy life expectancy (HALE) at birth (years)
#
#      Publish States  Year             WHO Region World Bank income group  \
# 1395      Published  1990  Eastern Mediterranean              Low-income
# ...

# %%
#Method 2
#df = df[['ColA','ColB',..]]
#just give the column names in the desired order

# %%
column_array = np.array(list(df.Country))

# %%
column_array
# Out:
# array(['Afghanistan', 'Afghanistan', 'Afghanistan', ..., 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe'], dtype='<U52')

# %%
df.iloc[[11,24,37],:]
# Out:
#         Country                       Indicator_id Publish States  Year  \
# 299     Albania   Life expectancy at birth (years)      Published  1990
# 3108     Angola   Life expectancy at birth (years)      Published  1990
# 2467  Argentina  Life expectancy at age 60 (years)      Published  1990
#
#      WHO Region World Bank income group         Sex  Display Value  Numeric  \
# 299      Europe     Lower-middle-income        Male             67     67.0
# 3108     Africa     Lower-middle-income  Both sexes             43     43.0
# 2467   Americas     Upper-middle-income  Both sexes             20     20.0
#
#       Low  High  Comments
# 299   NaN   NaN       NaN
# 3108  NaN   NaN       NaN
# 2467  NaN   NaN       NaN

# %% [markdown]
# ## <center>Great Success!</center>
